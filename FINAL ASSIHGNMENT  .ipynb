# %%
import pandas as pd

# %%
import numpy as np

# %%
#Instructions:
#1- Inspect Data
#3- Analyze Data using different techniques discussed in class
#4- Use Data Visualization to support the above-mentioned point
#5- Summarize your findings and data preprocessing strategy in a ppt

# %%
data= pd.read_csv('apps.csv')

# %%
data
# Out:
#       Unnamed: 0                                                App  \
# 0              0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1              1                                Coloring book moana
# 2              2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3              3                              Sketch - Draw & Paint
# 4              4              Pixel Draw - Number Art Coloring Book
# ...          ...                                                ...
# 9654       10836                                   Sya9a Maroc - FR
# 9655       10837                   Fr. Mike Schmitz Audio Teachings
# 9656       10838                             Parkinson Exercices FR
# 9657       10839                      The SCP Foundation DB fr nn5n
# 9658       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Rating  Reviews  Size Number of Installs  Type  \
# 0          ART_AND_DESIGN     4.1      159  19.0            10,000+  Free
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0               0
# App                      0
# Category                47
# Rating                1463
# Reviews                  0
# Size                  1227
# Number of Installs       0
# Type                     0
# Price                    0
# Content Rating           0
# Genres                   0
# Last Updated             0
# Current Ver              8
# Android Ver              2
# dtype: int64

# %%
print(data.dtypes)
# Out:
# Unnamed: 0              int64
# App                    object
# Category               object
# Rating                float64
# Reviews                 int64
# Size                  float64
# Number of Installs     object
# Type                   object
# Price                  object
# Content Rating         object
# Genres                 object
# Last Updated           object
# Current Ver            object
# Android Ver            object
# dtype: object

# %%
data.sort_values('Rating')
# Out:
#       Unnamed: 0                                      App  \
# 9228       10400  Familial Hypercholesterolaemia Handbook
# 7703        8820                           DS Creator 2.0
# 4986        5978            Truck Driving Test Class 3 BC
# 7758        8875                           DT future1 cam
# 6747        7806                              CR Magazine
# ...          ...                                      ...
# 9642       10824                                Cardio-FR
# 9643       10825                       Naruto & Boruto FR
# 9649       10831                 payermonstationnement.fr
# 9653       10835                                 FR Forms
# 9656       10838                   Parkinson Exercices FR
#
#                  Category  Rating  Reviews  Size Number of Installs  Type  \
# 9228              MEDICAL     1.0        2  33.0               100+  Free
# 7703                TOOLS     1.0        2   4.4               500+  Free
# ...

# %%
data['Rating'] = data['Rating'].fillna(method='ffill')

# %%
data
# Out:
#       Unnamed: 0                                                App  \
# 0              0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1              1                                Coloring book moana
# 2              2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3              3                              Sketch - Draw & Paint
# 4              4              Pixel Draw - Number Art Coloring Book
# ...          ...                                                ...
# 9654       10836                                   Sya9a Maroc - FR
# 9655       10837                   Fr. Mike Schmitz Audio Teachings
# 9656       10838                             Parkinson Exercices FR
# 9657       10839                      The SCP Foundation DB fr nn5n
# 9658       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Rating  Reviews  Size Number of Installs  Type  \
# 0          ART_AND_DESIGN     4.1      159  19.0            10,000+  Free
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0               0
# App                      0
# Category                47
# Rating                   0
# Reviews                  0
# Size                  1227
# Number of Installs       0
# Type                     0
# Price                    0
# Content Rating           0
# Genres                   0
# Last Updated             0
# Current Ver              8
# Android Ver              2
# dtype: int64

# %%
data.sort_values('Size')
# Out:
#       Unnamed: 0                                                App  \
# 4034        4977                        Ad Remove Plugin for App2SD
# 8912       10072                                   ExDialer PRO Key
# 209          209                                    Plugin:AOT v5.0
# 5938        6974                             Lollipop Launcher Plus
# 8644        9787                       ES Audio Player ( Shortcut )
# ...          ...                                                ...
# 9536       10713  My Earthquake Alerts - US & Worldwide Earthquakes
# 9546       10725                                          Posta App
# 9584       10765                    Chat For Strangers - Video Chat
# 9644       10826          Frim: get new friends on local chat rooms
# 9657       10839                      The SCP Foundation DB fr nn5n
#
#                  Category  Rating  Reviews  Size Number of Installs  Type  \
# 4034         PRODUCTIVITY     4.1       66   0.0             1,000+  Paid
# ...

# %%
#data['Size'] = data['Size'].astype('int64')

# %%
data['Size'] = data['Size'].fillna(data['Size'].mode()[0])

# %%
data
# Out:
#       Unnamed: 0                                                App  \
# 0              0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1              1                                Coloring book moana
# 2              2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3              3                              Sketch - Draw & Paint
# 4              4              Pixel Draw - Number Art Coloring Book
# ...          ...                                                ...
# 9654       10836                                   Sya9a Maroc - FR
# 9655       10837                   Fr. Mike Schmitz Audio Teachings
# 9656       10838                             Parkinson Exercices FR
# 9657       10839                      The SCP Foundation DB fr nn5n
# 9658       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Rating  Reviews  Size Number of Installs  Type  \
# 0          ART_AND_DESIGN     4.1      159  19.0            10,000+  Free
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0             0
# App                    0
# Category              47
# Rating                 0
# Reviews                0
# Size                   0
# Number of Installs     0
# Type                   0
# Price                  0
# Content Rating         0
# Genres                 0
# Last Updated           0
# Current Ver            8
# Android Ver            2
# dtype: int64

# %%
data = data.dropna(axis = 0)

# %%
data
# Out:
#       Unnamed: 0                                                App  \
# 0              0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1              1                                Coloring book moana
# 2              2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3              3                              Sketch - Draw & Paint
# 4              4              Pixel Draw - Number Art Coloring Book
# ...          ...                                                ...
# 9654       10836                                   Sya9a Maroc - FR
# 9655       10837                   Fr. Mike Schmitz Audio Teachings
# 9656       10838                             Parkinson Exercices FR
# 9657       10839                      The SCP Foundation DB fr nn5n
# 9658       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Rating  Reviews  Size Number of Installs  Type  \
# 0          ART_AND_DESIGN     4.1      159  19.0            10,000+  Free
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0            0
# App                   0
# Category              0
# Rating                0
# Reviews               0
# Size                  0
# Number of Installs    0
# Type                  0
# Price                 0
# Content Rating        0
# Genres                0
# Last Updated          0
# Current Ver           0
# Android Ver           0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data.corr()
# Out:
#             Unnamed: 0    Rating   Reviews      Size
# Unnamed: 0    1.000000 -0.089908 -0.096395 -0.054409
# Rating       -0.089908  1.000000  0.047584  0.040353
# Reviews      -0.096395  0.047584  1.000000  0.064752
# Size         -0.054409  0.040353  0.064752  1.000000

# %%
sns.regplot(x="Reviews",y="Rating",data=data)
# Out:
# <AxesSubplot:xlabel='Reviews', ylabel='Rating'>

# %%
data['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
grouped_test1 = data.groupby('Category',as_index=False)['Category','Rating'].mean().sort_values('Rating', ascending=False).head(10)
grouped_test1
# Out:
# <ipython-input-162-3c726f9bda8c>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped_test1 = data.groupby('Category',as_index=False)['Category','Rating'].mean().sort_values('Rating', ascending=False).head(10)
#                Category    Rating
# 10               EVENTS  4.400000
# 0        ART_AND_DESIGN  4.390909
# 8             EDUCATION  4.367227
# 22            PARENTING  4.295000
# 3   BOOKS_AND_REFERENCE  4.291855
# 23      PERSONALIZATION  4.286364
# 2                BEAUTY  4.262264
# 27               SOCIAL  4.254338
# 28               SPORTS  4.245938
# 14                 GAME  4.245047

# %%
grouped_test1.columns
# Out:
# Index(['Category', 'Rating'], dtype='object')

# %%
sns.regplot("Category",y="Rating",data=grouped_test1)
# Out:
# C:\Users\mk\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-164-e2a0032eec9b> in <module>
# ----> 1 sns.regplot("Category",y="Rating",data=grouped_test1)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...
